# %%
import pandas as pd

# %%
df = pd.read_csv('craftcans.csv')
df
# Out:
#                           Beer              Brewery         Location  \
# 0                 Get Together    NorthGate Brewing  Minneapolis, MN
# 1                Maggie's Leap    NorthGate Brewing  Minneapolis, MN
# 2                   Wall's End    NorthGate Brewing  Minneapolis, MN
# 3                      Pumpion    NorthGate Brewing  Minneapolis, MN
# 4                   Stronghold    NorthGate Brewing  Minneapolis, MN
# ...                        ...                  ...              ...
# 2411  Mama's Little Yella Pils  Oskar Blues Brewery     Longmont, CO
# 2412        GUBNA Imperial IPA  Oskar Blues Brewery     Longmont, CO
# 2413                  Old Chub  Oskar Blues Brewery     Longmont, CO
# 2414         Gordon Ale (2009)  Oskar Blues Brewery     Longmont, CO
# 2415           Dale's Pale Ale  Oskar Blues Brewery     Longmont, CO
#
#                                Style    Size    ABV IBUs
# 0                       American IPA  16 oz.  4.50%   50
# ...

# %%
df = pd.DataFrame
data = "craftcans.csv"
import pandas as pd
df = pd.DataFrame

# %%
df.head()
# Out:
#             Beer            Brewery         Location               Style  \
# 0   Get Together  NorthGate Brewing  Minneapolis, MN        American IPA
# 1  Maggie's Leap  NorthGate Brewing  Minneapolis, MN  Milk / Sweet Stout
# 2     Wall's End  NorthGate Brewing  Minneapolis, MN   English Brown Ale
# 3        Pumpion  NorthGate Brewing  Minneapolis, MN         Pumpkin Ale
# 4     Stronghold  NorthGate Brewing  Minneapolis, MN     American Porter
#
#      Size    ABV IBUs
# 0  16 oz.  4.50%   50
# 1  16 oz.  4.90%   26
# 2  16 oz.  4.80%   19
# 3  16 oz.  6.00%   38
# 4  16 oz.  6.00%   25

# %%
df.shape

# %%
df['IBUs'].largest(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/greenfroggyz/Downloads/true-3/beer/Dataset ONE - Beer cans.ipynb Cell 12' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/greenfroggyz/Downloads/true-3/beer/Dataset%20ONE%20-%20Beer%20cans.ipynb#ch0000013?line=0'>1</a> df['IBUs'].largest(10)
#
# TypeError: 'type' object is not subscriptable

# %%
def most_common(lst):
    data = ABV(lst)

# %%
df_mean = df["ABV"].mean()

# %%
df.dtypes
df
df.ABV = df.ABV.str.replace('%','')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/greenfroggyz/Downloads/true-3/beer/Dataset ONE - Beer cans.ipynb Cell 9' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/greenfroggyz/Downloads/true-3/beer/Dataset%20ONE%20-%20Beer%20cans.ipynb#ch0000017?line=0'>1</a> df.dtypes
#       <a href='vscode-notebook-cell:/Users/greenfroggyz/Downloads/true-3/beer/Dataset%20ONE%20-%20Beer%20cans.ipynb#ch0000017?line=1'>2</a> df
#       <a href='vscode-notebook-cell:/Users/greenfroggyz/Downloads/true-3/beer/Dataset%20ONE%20-%20Beer%20cans.ipynb#ch0000017?line=2'>3</a> df.ABV = df.ABV.str.replace('%','')
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#                           Beer              Brewery         Location  \
# 0                 Get Together    NorthGate Brewing  Minneapolis, MN
# 1                Maggie's Leap    NorthGate Brewing  Minneapolis, MN
# 2                   Wall's End    NorthGate Brewing  Minneapolis, MN
# 3                      Pumpion    NorthGate Brewing  Minneapolis, MN
# 4                   Stronghold    NorthGate Brewing  Minneapolis, MN
# ...                        ...                  ...              ...
# 2411  Mama's Little Yella Pils  Oskar Blues Brewery     Longmont, CO
# 2412        GUBNA Imperial IPA  Oskar Blues Brewery     Longmont, CO
# 2413                  Old Chub  Oskar Blues Brewery     Longmont, CO
# 2414         Gordon Ale (2009)  Oskar Blues Brewery     Longmont, CO
# 2415           Dale's Pale Ale  Oskar Blues Brewery     Longmont, CO
#
#                                Style    Size   ABV IBUs
# 0                       American IPA  16 oz.  4.50   50
# ...

# %%
df_mean = df['ABV']

# %%
df['ABV'].isna().sum()
# Out:
# 68

# %%
df['Location'].value_counts().head(10)
# Out:
# Grand Rapids, MI    66
# Chicago, IL         55
# Portland, OR        52
# Indianapolis, IN    43
# San Diego, CA       42
# Boulder, CO         41
# Denver, CO          40
# Brooklyn, NY        38
# Seattle, WA         35
# Longmont, CO        33
# Name: Location, dtype: int64

# %%
df[df.Location == "Brooklyn, NY"]
# Out:
#                                  Beer              Brewery      Location  \
# 115                            4Beans  Sixpoint Craft Ales  Brooklyn, NY
# 210                            Jammer  Sixpoint Craft Ales  Brooklyn, NY
# 246                           Abigale  Sixpoint Craft Ales  Brooklyn, NY
# 404                     Nomader Weiss    Evil Twin Brewing  Brooklyn, NY
# 421                               Rad  Sixpoint Craft Ales  Brooklyn, NY
# 439                      Molotov Lite    Evil Twin Brewing  Brooklyn, NY
# 588                           Bengali  Sixpoint Craft Ales  Brooklyn, NY
# 713                     Sensi Harvest  Sixpoint Craft Ales  Brooklyn, NY
# 969                            Hi-Res  Sixpoint Craft Ales  Brooklyn, NY
# 987             KelSo Nut Brown Lager   KelSo Beer Company  Brooklyn, NY
# 1057                    Global Warmer  Sixpoint Craft Ales  Brooklyn, NY
# 1074               Autumnation (2013)  Sixpoint Craft Ales  Brooklyn, NY
# ...

# %%
df.groupby('Location').sum
# Out:
# <bound method GroupBy.sum of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x12db7c250>>

# %%
df[df.Brewery == "Sixpoint Craft Ales"].head(5)
# Out:
#         Beer              Brewery      Location                   Style  \
# 115   4Beans  Sixpoint Craft Ales  Brooklyn, NY           Baltic Porter
# 210   Jammer  Sixpoint Craft Ales  Brooklyn, NY                    Gose
# 246  Abigale  Sixpoint Craft Ales  Brooklyn, NY        Belgian Pale Ale
# 421      Rad  Sixpoint Craft Ales  Brooklyn, NY  Fruit / Vegetable Beer
# 588  Bengali  Sixpoint Craft Ales  Brooklyn, NY            American IPA
#
#                   Size    ABV            IBUs
# 115             12 oz.  10.00              52
# 210    12 oz. Slimline   4.20              16
# 246             12 oz.   8.00  Does not apply
# 421             16 oz.   3.20               7
# 588  24 oz. "Silo Can"   6.50              62

# %%
df[df.Location.str.contains('NY', na=False)]
# Out:
#                           Beer                  Brewery           Location  \
# 115                     4Beans      Sixpoint Craft Ales       Brooklyn, NY
# 210                     Jammer      Sixpoint Craft Ales       Brooklyn, NY
# 246                    Abigale      Sixpoint Craft Ales       Brooklyn, NY
# 404              Nomader Weiss        Evil Twin Brewing       Brooklyn, NY
# 421                        Rad      Sixpoint Craft Ales       Brooklyn, NY
# ...                        ...                      ...                ...
# 2351   Brooklyn Lager (12 oz.)         Brooklyn Brewery       Brooklyn, NY
# 2364  Heinnieweisse Weissebier  Butternuts Beer and Ale  Garrattsville, NY
# 2365           Snapperhead IPA  Butternuts Beer and Ale  Garrattsville, NY
# 2366         Moo Thunder Stout  Butternuts Beer and Ale  Garrattsville, NY
# 2367         Porkslap Pale Ale  Butternuts Beer and Ale  Garrattsville, NY
#
# ...

# %%
df[df.Location.str.contains('NY', na=False)].count()
# Out:
# Beer        74
# Brewery     74
# Location    74
# Style       74
# Size        74
# ABV         73
# IBUs        74
# dtype: int64

# %%
df[df.Style.str.contains('IPA', na=False)].count()
# Out:
# Beer        571
# Brewery     571
# Location    571
# Style       571
# Size        571
# ABV         560
# IBUs        571
# dtype: int64

# %%
df.IBUs.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0        50
# 1        26
# 2        19
# 3        38
# 4        25
#        ...
# 2411     35
# 2412    100
# 2413     35
# 2414     85
# 2415     65
# Name: IBUs, Length: 2416, dtype: object>

# %%
df[df.Style.str.contains('IPA', >75, na=False)].count()
# Out:
#   Input In [162]
#     df[df.Style.str.contains('IPA', >75, na=False)].count()
#                                     ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

# %%
df.plot([x == "IBUs"]).median()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/greenfroggyz/Downloads/true-3/beer/Dataset ONE - Beer cans.ipynb Cell 50' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/greenfroggyz/Downloads/true-3/beer/Dataset%20ONE%20-%20Beer%20cans.ipynb#ch0000051?line=0'>1</a> df.plot([x == "IBUs"]).median()
#       <a href='vscode-notebook-cell:/Users/greenfroggyz/Downloads/true-3/beer/Dataset%20ONE%20-%20Beer%20cans.ipynb#ch0000051?line=1'>2</a> plt.show()
#
# NameError: name 'x' is not defined

# %%
df.hist[df.Style.str.contains('IPA', na=False)].count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/greenfroggyz/Downloads/true-3/beer/Dataset ONE - Beer cans.ipynb Cell 53' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/greenfroggyz/Downloads/true-3/beer/Dataset%20ONE%20-%20Beer%20cans.ipynb#ch0000056?line=0'>1</a> df.hist[df.Style.str.contains('IPA', na=False)].count()
#
# TypeError: 'method' object is not subscriptable

# %%
wheat = df[df.Style.isin(['Witbier','Hefeweizen', 'American Pale Wheat Ale'])]

# %%
wheat.head()
# Out:
#              Beer                       Brewery           Location  \
# 30           Park       Fort Point Beer Company  San Francisco, CA
# 42     Whitewater  Great Divide Brewing Company         Denver, CO
# 72    Citra Faced           Three Pints Brewing   Martinsville, IN
# 112  Summer Wheat        Anchor Brewing Company  San Francisco, CA
# 138   Waterkeeper    SweetWater Brewing Company        Atlanta, GA
#
#                        Style    Size    ABV            IBUs
# 30   American Pale Wheat Ale  12 oz.  4.70%              19
# 42   American Pale Wheat Ale  12 oz.  6.10%  Does not apply
# 72   American Pale Wheat Ale  16 oz.  5.50%              64
# 112  American Pale Wheat Ale  12 oz.  4.50%  Does not apply
# 138               Hefeweizen  12 oz.  5.70%  Does not apply

# %%
wheat = wheat[wheat.IBUs != "Does not apply"]
wheat
# Out:
#                                  Beer                           Brewery  \
# 30                               Park           Fort Point Beer Company
# 72                        Citra Faced               Three Pints Brewing
# 139                     Weissenheimer                   Destihl Brewery
# 167                           Rye Wit          Freetail Brewing Company
# 230                  Blackberry Wheat  Kirkwood Station Brewing Company
# ...                               ...                               ...
# 2296     Morning Wood Wheat (Current)                Pug Ryan's Brewery
# 2312                     White Rascal             Avery Brewing Company
# 2334        Haywire Hefeweizen (2010)                 Pyramid Breweries
# 2383  Montana Trout Slayer Ale (2009)           Big Sky Brewing Company
# 2396                 Royal Weisse Ale           Sly Fox Brewing Company
#
#                Location                    Style    Size    ABV IBUs
# ...

# %%
wheat.IBUs.mean()
# Out:
# 1.7537151886446608e+213

# %%
pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 31.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.9/930.9 KB 20.1 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 30.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.3/65.3 KB 2.5 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
df['IBUs'].hist()
# Out:
# <AxesSubplot:>

# %%
df['IBUs'].hist()
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv('craftcans.csv')

# %%
df[df.Style.str.contains('IPA', na=False)].ABV.describe()
# Out:
# count       560
# unique       61
# top       7.00%
# freq         62
# Name: ABV, dtype: object

# %%
df[df.style.str.contains('wheat', na=False)].ABV.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/greenfroggyz/Downloads/true-3/beer/Dataset ONE - Beer cans.ipynb Cell 73' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/greenfroggyz/Downloads/true-3/beer/Dataset%20ONE%20-%20Beer%20cans.ipynb#ch0000071?line=0'>1</a> df[df.style.str.contains('wheat', na=False)].ABV.describe()
#
# AttributeError: 'Styler' object has no attribute 'str'

# %%
pip install Jinja2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.1/133.1 KB 3.6 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
wheat.ABV.describe()
# Out:
# count       112
# unique       27
# top       5.00%
# freq         27
# Name: ABV, dtype: object
